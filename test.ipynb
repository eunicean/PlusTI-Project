# %% [markdown]
# # Análisis Exploratorio y Feature Engineering — Detección de Fraude Federado
# ### Datasets Bancos: BO VIP, BR PRIVADO, GT ESTATAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings
import os
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 80)
pd.set_option("display.float_format", "{:.4f}".format)
sns.set_theme(style="whitegrid", palette="muted")

# %%
DATA_DIR = r"Copia de Datasets 3 bancos"
FILES = {
    "BO_VIP":    os.path.join(DATA_DIR, "Copia de 01_bo_vip_seed22_n100000.csv"),
    "BR_PRIVATE": os.path.join(DATA_DIR, "Copia de 02_br_privado_seed33_n100000.csv"),
    "GT_STATE":  os.path.join(DATA_DIR, "Copia de 03_gt_estatal_seed3_n100000.csv"),
}

# %% [markdown]
# ---
# ## Carga de Datos

# %%
dfs_raw = {}
for name, path in FILES.items():
    df = pd.read_csv(path, sep=";", low_memory=False)
    df["source_bank"] = name
    dfs_raw[name] = df
    print(f"[{name}] shape: {df.shape}\n  - is_fraud nulos: {df['is_fraud'].isna().sum()}")
# Out:
# [BO_VIP] shape: (100003, 67)
#   - is_fraud nulos: 0
# [BR_PRIVATE] shape: (100000, 67)
#   - is_fraud nulos: 0
# [GT_STATE] shape: (100000, 67)
#   - is_fraud nulos: 100000

# %%
#transacciones duplicadas 
bo = dfs_raw["BO_VIP"]
br = dfs_raw["BR_PRIVATE"]
gt = dfs_raw["GT_STATE"]
print(bo['transaction_id'].duplicated().sum())
print(br['transaction_id'].duplicated().sum())
print(gt['transaction_id'].duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
bo
# Out:
#                               transaction_id bank_code bank_name bank_country  \
# 0       7dd812b1-bd03-4d05-afc6-c318dcc9b651    BO-VIP    BO-VIP           BO
# 1       c08b49a6-889a-491a-a1f8-974526f7886d    BO-VIP    BO-VIP           BO
# 2       b04f88bd-2e33-42e5-a3cf-d52ef22dd7d9    BO-VIP    BO-VIP           BO
# 3       3a836c25-7a8c-473b-8141-3e84ba3f212d    BO-VIP    BO-VIP           BO
# 4       be9956da-924f-4c68-aed8-f0c5d949e577    BO-VIP    BO-VIP           BO
# ...                                      ...       ...       ...          ...
# 99998   09759a72-7465-4b19-bfbe-384d1c010387    BO-VIP    BO-VIP           BO
# 99999   486b9c70-eea1-4f99-a788-b0b1d092a665    BO-VIP    BO-VIP           BO
# 100000  34c08149-00bc-44ea-b8af-022856035cf0    BO-VIP    BO-VIP           BO
# 100001  8c7d037a-19b5-41fc-ac60-6af9e3e24fc2    BO-VIP    BO-VIP           BO
# 100002  cc4716fb-1ee8-4f24-8083-24e419c55d2d    BO-VIP    BO-VIP           BO
#
#        bank_tier           client_id client_segment channel  card_brand  \
# 0            vip  BO-VIP-CL-00001325       PLATINUM     POS  MASTERCARD
# 1            vip  BO-VIP-CL-00000079        PRIVATE    ECOM        VISA
# 2            vip  BO-VIP-CL-00002344       INFINITE    ECOM         NaN
# 3            vip  BO-VIP-CL-00002587       PLATINUM     ATM        VISA
# 4            vip  BO-VIP-CL-00000087        PRIVATE     POS        VISA
# ...          ...                 ...            ...     ...         ...
# 99998        vip  BO-VIP-CL-00001367        PRIVATE    MOTO  MASTERCARD
# 99999        vip  BO-VIP-CL-00002419       PLATINUM    ECOM        VISA
# 100000       vip  BO-VIP-CL-00000413        PRIVATE    ECOM        VISA
# 100001       vip  BO-VIP-CL-00001873          BLACK    MOTO        VISA
# 100002       vip  BO-VIP-CL-00000133          BLACK     POS  MASTERCARD
#
#               pan_masked                                           pan_hash  \
# 0       531270******3773  e253ee7d060689e75077b0c7d85d995bf4ba104a7a931e...
# 1       421250******5552  9de2ffd889d660bc1d350aff8143484eaab5246c0c3f31...
# 2       531270******6104  14d38149e4bcdeffed96229129ba6d359b477780d24ba0...
# 3       479500******0288  7ff3ca034215fd90c2019b8762e9493cc5867dff207082...
# 4       479500******0249  bdc9c9f8a47332f4833214c4f90e7a1b88b606d52aec00...
# ...                  ...                                                ...
# 99998   531270******0087  771123f02892e249b959b9bacd602eb86287c3fd745f4e...
# 99999   421250******8268  ed82fc52d9987628dbc9601f6ea773075dbaf01b1fa41d...
# 100000  479500******3622  0e7e66792b05a55b2369e5cfea4279d97d580fac6e4014...
# 100001  479500******8097  e118c1c8f385f81416a041bf0d292dd1ae01f343a5efc5...
# 100002  531270******9930  449432a1f2316aeff1be7b1843380eff67c2797db1aabf...
#
#         MTI               DE2_PAN  DE3_processing_code  \
# 0       100 5312700000000000.0000                    0
# 1       100 4212500000000000.0000                    0
# 2       100 5312700000000000.0000                    0
# 3       100 4795000000000000.0000                10000
# 4       100 4795000000000000.0000                    0
# ...     ...                   ...                  ...
# 99998   100 5312710000000000.0000                    0
# 99999   100 4212500000000000.0000                    0
# 100000  100 4795010000000000.0000                    0
# 100001  100 4795010000000000.0000                    0
# 100002  100 5312710000000000.0000                    0
#
#         DE4_amount_transaction  DE6_amount_cardholder_billing  \
# 0                        39379                         345082
# 1                      1310264                        1310264
# 2                       241394                         241394
# 3                        31416                         238449
# 4                        82038                          82038
# ...                        ...                            ...
# 99998                   171550                         171550
# 99999                   195019                         195019
# 100000                  133208                         133208
# 100001                   83624                          83624
# 100002                  225624                        1556804
#
#         DE7_transmission_datetime  DE9_conversion_rate_billing  DE11_STAN  \
# 0                       101000151                87630970.0000     947249
# 1                       101000355                10000000.0000       7687
# 2                       101000410                10000000.0000     979481
# 3                       101000453                75900496.0000     915846
# 4                       101000756                10000000.0000     943975
# ...                           ...                          ...        ...
# 99998                   629235203                10000000.0000     914985
# 99999                   629235219                10000000.0000        496
# 100000                  629235759                10000000.0000       4552
# 100001                  629235924                10000000.0000     985957
# 100002                  630001336                68999943.0000     926501
#
#         DE12_local_time  DE13_local_date  DE14_expiration_date  \
# 0                200151             1231                  2901
# 1                200355             1231                  2907
# 2                200410             1231                  2610
# 3                200453             1231                  2710
# 4                200756             1231                  3004
# ...                 ...              ...                   ...
# 99998            195203              629                  2904
# 99999            195219              629                  2809
# 100000           195759              629                  2610
# 100001           195924              629                  2908
# 100002           201336              629                  2711
#
#         DE15_settlement_date  DE18_merchant_category_code  \
# 0                   101.0000                         5651
# 1                   101.0000                         4511
# 2                   101.0000                         5732
# 3                   101.0000                         6011
# 4                   101.0000                         5812
# ...                      ...                          ...
# 99998               630.0000                         7011
# 99999               630.0000                         5732
# 100000              630.0000                         5311
# 100001              630.0000                         5967
# 100002              630.0000                         4511
#
#         DE19_acquirer_country_code  DE22_pos_entry_mode  DE23_card_seq_number  \
# 0                              826                   72                1.0000
# 1                               68                   81                2.0000
# 2                               68                   81                2.0000
# 3                              250                   51                2.0000
# 4                               68                   21                3.0000
# ...                            ...                  ...                   ...
# 99998                           68                   10                2.0000
# 99999                           68                   81                2.0000
# 100000                          68                   81                2.0000
# 100001                          68                   10                2.0000
# 100002                         840                   51                1.0000
#
#         DE25_pos_condition_code  DE32_acquiring_institution_id  \
# 0                             0                    14484680068
# 1                            59                    14484680068
# 2                            59                    14484680068
# 3                             0                    14484680068
# 4                             0                    14484680068
# ...                         ...                            ...
# 99998                         8                    14484680068
# 99999                        59                    14484680068
# 100000                       59                    14484680068
# 100001                        8                    14484680068
# 100002                        0                    14484680068
#
#          DE35_track2_data_masked DE37_retrieval_reference_number  \
# 0       531270******3773=2901201                    TEBBJIQJPQP9
# 1       421250******5552=2907201                    115BVLO5H5F0
# 2       531270******6104=2610201                    NUKM3XFSZVJX
# 3       479500******0288=2710201                    BF4EW9A6R844
# 4       479500******0249=3004201                    S6QRPTMN6WAD
# ...                          ...                             ...
# 99998   531270******0087=2904201                    26B8M3TY3ZQU
# 99999   421250******8268=2809201                    28HG4R33LI2S
# 100000  479500******3622=2610201                    9HM6I2S7MM9L
# 100001  479500******8097=2908201                    1VABEW3J8P9M
# 100002  531270******9930=2711201                    YH0BMZF9NNDQ
#
#        DE38_authorization_code  DE39_response_code DE41_terminal_id  \
# 0                       17P76V                   0         BO-23325
# 1                       48D1XM                   0         BO-34705
# 2                       PFIGFD                   0         BO-31334
# 3                       7Z9YO7                   0         BO-65992
# 4                       KL6D9H                   0         BO-93457
# ...                        ...                 ...              ...
# 99998                   FQ3GQ3                   0         BO-52824
# 99999                   XTGPTU                   0         BO-89932
# 100000                  CZINJ9                   0         BO-72306
# 100001                  VDJVGF                   0         BO-30625
# 100002                  B5RXNL                   0         BO-60427
#
#        DE42_card_acceptor_id          DE43_card_acceptor_name_location  \
# 0            M74178102540833  LEVIS STORE           LONDON       GB
# 1            M95802681578714  IBERIA                LAPAZ        BO
# 2            M28333044130009  AMAZON ELECTRO        SANTACRUZ    BO
# 3            M76079092139715  ATM RED LINK          PARIS        FR
# 4            M55941189713950  BISTRO DEL CENTRO     COCHABAMBA   BO
# ...                      ...                                       ...
# 99998        M91393396964986  MARRIOTT RESORT       LAPAZ        BO
# 99999        M48740026452746  LINIO ELECTRONICA     TARIJA       BO
# 100000       M45651592762631  RIPLEY STORE          SUCRE        BO
# 100001       M92884012620291  TELEMARKETING DIGITAL TARIJA       BO
# 100002       M27296734540937  GOL AIRLINES          MIAMI        US
#
#        DE44_additional_response_data  DE48_additional_data  \
# 0                                NaN                   NaN
# 1                                NaN                   NaN
# 2                                NaN                   NaN
# 3                                NaN                   NaN
# 4                                NaN                   NaN
# ...                              ...                   ...
# 99998                            NaN                   NaN
# 99999                            NaN                   NaN
# 100000                           NaN                   NaN
# 100001                           NaN                   NaN
# 100002                           NaN                   NaN
#
#         DE49_currency_code_transaction  DE50_currency_code_settlement  \
# 0                                  826                             68
# 1                                   68                             68
# 2                                   68                             68
# 3                                  978                             68
# 4                                   68                             68
# ...                                ...                            ...
# 99998                               68                             68
# 99999                               68                             68
# 100000                              68                             68
# 100001                              68                             68
# 100002                             840                             68
#
#         DE51_currency_code_billing DE52_pin_data_present  \
# 0                               68                     N
# 1                               68                     N
# 2                               68                     N
# 3                               68                     Y
# 4                               68                     Y
# ...                            ...                   ...
# 99998                           68                     N
# 99999                           68                     N
# 100000                          68                     N
# 100001                          68                     N
# 100002                          68                     Y
#
#         DE54_additional_amounts DE55_emv_data_present  DE56_original_data  \
# 0                           NaN                     N                 NaN
# 1                           NaN                     N                 NaN
# 2                           NaN                     N                 NaN
# 3                           NaN                     Y                 NaN
# 4                           NaN                     N                 NaN
# ...                         ...                   ...                 ...
# 99998                       NaN                     N                 NaN
# 99999                       NaN                     N                 NaN
# 100000                      NaN                     N                 NaN
# 100001                      NaN                     N                 NaN
# 100002                      NaN                     Y                 NaN
#
#         DE58_authorizing_agent_id DE60_pos_terminal_type  \
# 0                14484680068.0000           POS-ATTENDED
# 1                14484680068.0000           ECOM-VIRTUAL
# 2                14484680068.0000           ECOM-VIRTUAL
# 3                14484680068.0000         ATM-UNATTENDED
# 4                14484680068.0000           POS-ATTENDED
# ...                           ...                    ...
# 99998            14484680068.0000             MOTO-CLERK
# 99999            14484680068.0000           ECOM-VIRTUAL
# 100000           14484680068.0000           ECOM-VIRTUAL
# 100001           14484680068.0000             MOTO-CLERK
# 100002           14484680068.0000           POS-ATTENDED
#
#         DE61_pos_extended_data DE63_network_specific  \
# 0                       0.0000                BO-VIP
# 1                      59.0000                BO-VIP
# 2                      59.0000                BO-VIP
# 3                       0.0000                BO-VIP
# 4                       0.0000                BO-VIP
# ...                        ...                   ...
# 99998                   8.0000                BO-VIP
# 99999                  59.0000                BO-VIP
# 100000                 59.0000                BO-VIP
# 100001                  8.0000                BO-VIP
# 100002                  0.0000                BO-VIP
#
#         DE100_receiving_institution_id DE102_account_id_1  DE103_account_id_2  \
# 0                     14484680068.0000    ACC774404459020                 NaN
# 1                     14484680068.0000    ACC620405269742                 NaN
# 2                     14484680068.0000    ACC606260684104                 NaN
# 3                     14484680068.0000    ACC743423920527                 NaN
# 4                     14484680068.0000    ACC988775152881                 NaN
# ...                                ...                ...                 ...
# 99998                 14484680068.0000    ACC480339041727                 NaN
# 99999                 14484680068.0000    ACC279303518687                 NaN
# 100000                14484680068.0000    ACC504553813339                 NaN
# 100001                14484680068.0000    ACC994616308135                 NaN
# 100002                14484680068.0000    ACC876825756527                 NaN
#
#        DE123_pos_data_code  amount_local  amount_tx_currency  \
# 0                   07200N     3450.8200            393.7900
# 1                   08159N    13102.6400          13102.6400
# 2                   08159N     2413.9400           2413.9400
# 3                   05100Y     2384.4900            314.1600
# 4                   02100Y      820.3800            820.3800
# ...                    ...           ...                 ...
# 99998               01008N     1715.5000           1715.5000
# 99999               08159N     1950.1900           1950.1900
# 100000              08159N     1332.0800           1332.0800
# 100001              01008N      836.2400            836.2400
# 100002              05100Y    15568.0400           2256.2400
#
#        currency_tx_alpha  amount_usd  is_international  distance_from_home_km  \
# 0                    GBP    500.1200              True              8717.0000
# 1                    BOB   1898.9300             False                 4.9000
# 2                    BOB    349.8500             False                 4.4000
# 3                    EUR    345.5800              True              3966.0000
# 4                    BOB    118.9000             False               348.0000
# ...                  ...         ...               ...                    ...
# 99998                BOB    248.6200             False              1057.0000
# 99999                BOB    282.6400             False                15.5000
# 100000               BOB    193.0600             False               854.0000
# 100001               BOB    121.1900             False                 1.6000
# 100002               USD   2256.2400              True              9647.0000
#
#         hour_local day_of_week  approved response_description  \
# 0               20         Tue      True             Approved
# 1               20         Tue      True             Approved
# 2               20         Tue      True             Approved
# 3               20         Tue      True             Approved
# 4               20         Tue      True                  NaN
# ...            ...         ...       ...                  ...
# 99998           19         Sun      True             Approved
# 99999           19         Sun      True             Approved
# 100000          19         Sun      True             Approved
# 100001          19         Sun      True             Approved
# 100002          20         Sun      True             Approved
#
#         client_baseline_amount client_home_city  is_fraud source_bank
# 0                    2012.5100           TARIJA     False      BO_VIP
# 1                    1096.4600            LAPAZ     False      BO_VIP
# 2                    1528.3700        SANTACRUZ     False      BO_VIP
# 3                    2483.3400            SUCRE     False      BO_VIP
# 4                    1334.5500            SUCRE     False      BO_VIP
# ...                        ...              ...       ...         ...
# 99998                2192.0700            ORURO     False      BO_VIP
# 99999                 735.1200           TARIJA     False      BO_VIP
# 100000                828.5200       COCHABAMBA     False      BO_VIP
# 100001                909.8500           TARIJA     False      BO_VIP
# 100002               2296.2300            LAPAZ      True      BO_VIP
#
# [100003 rows x 67 columns]

# %%
br
# Out:
#                              transaction_id bank_code bank_name bank_country  \
# 0      49b290bb-4479-4367-950d-ed7d9bdc96d0    BR-PRI    BR-PRI           BR
# 1      0697c7b6-b5ab-4ab5-8684-4f3fcdd54ff2    BR-PRI    BR-PRI           BR
# 2      ac73c4c0-ca7d-48b8-ad18-ab6dcc48819c    BR-PRI    BR-PRI           BR
# 3      b0e4e6d3-9b43-44c8-8fd2-37598de9aaad    BR-PRI    BR-PRI           BR
# 4      557549be-eed1-476d-8a1d-f6a2ae02518f    BR-PRI    BR-PRI           BR
# ...                                     ...       ...       ...          ...
# 99995  fad5b1a1-1216-4c68-a109-00116a0e2ab6    BR-PRI    BR-PRI           BR
# 99996  6f8876e2-14b4-4244-9439-be91dc4c9500    BR-PRI    BR-PRI           BR
# 99997  85c284a9-9d49-4c8b-ae09-ba040fdcf4f9    BR-PRI    BR-PRI           BR
# 99998  3d169384-dc8d-443a-a942-eebe964bc5bb    BR-PRI    BR-PRI           BR
# 99999  517f8a36-e020-4b32-a793-94cff7e95a09    BR-PRI    BR-PRI           BR
#
#       bank_tier           client_id client_segment channel  card_brand  \
# 0       privado  BR-PRI-CL-00003011        CLASICA     POS        VISA
# 1       privado  BR-PRI-CL-00000292            ORO     POS        VISA
# 2       privado  BR-PRI-CL-00002993        CLASICA     ATM  MASTERCARD
# 3       privado  BR-PRI-CL-00002693        CLASICA     ATM        VISA
# 4       privado  BR-PRI-CL-00000045        PLATINO     POS  MASTERCARD
# ...         ...                 ...            ...     ...         ...
# 99995   privado  BR-PRI-CL-00003744        PLATINO     ATM        VISA
# 99996   privado  BR-PRI-CL-00001235        CLASICA     POS  MASTERCARD
# 99997   privado  BR-PRI-CL-00002558        PLATINO     ATM        VISA
# 99998   privado  BR-PRI-CL-00001218            ORO     ATM  MASTERCARD
# 99999   privado  BR-PRI-CL-00002558        PLATINO     ATM        VISA
#
#              pan_masked                                           pan_hash  \
# 0      422355******4250  cde43f85cf5ec9d005e8a539bc2e540a442e43af7a5577...
# 1      422355******2908  b1a76140549f19c2367462d823e0d2d1897c53e3968b9e...
# 2      541333******2878  c5f1cc61d76ee0c47fca1b4bab64fa773df3cbf9e00dfe...
# 3      422355******0490  6bb430c9ad26e0913273db4937ac84d6eea46bc34e851a...
# 4      533421******0731  3cbd84e1c03ebaec7a4a1a98e0f4f693470e49aaa0eea6...
# ...                 ...                                                ...
# 99995  422355******1641  1f3a3c8b67989b4104f9ee89107cff94da93443dae9c7c...
# 99996  533421******2374  b9adc6d796810d5eb26750e79e7f8e88d496b03dfd2aec...
# 99997  422355******1381  330b21425c1b5eba95d5b58502816c198386105e5105d4...
# 99998  541333******1792  3216c2ff87fe6e6f2a11df90ffad5a57fc584a45d7506c...
# 99999  422355******1381  330b21425c1b5eba95d5b58502816c198386105e5105d4...
#
#        MTI               DE2_PAN  DE3_processing_code  DE4_amount_transaction  \
# 0      100 4223550000000000.0000                    0                    7461
# 1      100 4223560000000000.0000                    0                   29162
# 2      100 5413340000000000.0000                10000                   24950
# 3      100 4223560000000000.0000                10000                   20485
# 4      100 5334220000000000.0000                    0                    7160
# ...    ...                   ...                  ...                     ...
# 99995  100 4223550000000000.0000                10000                   73597
# 99996  100 5334210000000000.0000                    0                   65907
# 99997  100 4223550000000000.0000                10000                 4553049
# 99998  100 5413340000000000.0000                10000                  185932
# 99999  100 4223550000000000.0000                10000                  198884
#
#        DE6_amount_cardholder_billing  DE7_transmission_datetime  \
# 0                               7461                  101000221
# 1                              29162                  101000350
# 2                              24950                  101000533
# 3                              20485                  101001208
# 4                              35801                  101001602
# ...                              ...                        ...
# 99995                          73597                  629235656
# 99996                          65907                  629235658
# 99997                         151768                  630022106
# 99998                         185932                  630061432
# 99999                         198884                  701015751
#
#        DE9_conversion_rate_billing  DE11_STAN  DE12_local_time  \
# 0                    10000000.0000     749972           210221
# 1                    10000000.0000     751009           210350
# 2                    10000000.0000     693786           210533
# 3                    10000000.0000     733323           211208
# 4                    50001396.0000     759060           211602
# ...                            ...        ...              ...
# 99995                10000000.0000     722563           205656
# 99996                10000000.0000     718548           205658
# 99997                  333333.0000     733475           232106
# 99998                10000000.0000     694864            31432
# 99999                10000000.0000     733476           225751
#
#        DE13_local_date  DE14_expiration_date  DE15_settlement_date  \
# 0                 1231                  2705              101.0000
# 1                 1231                  2902              101.0000
# 2                 1231                  2610              101.0000
# 3                 1231                  2807              101.0000
# 4                 1231                  2903              101.0000
# ...                ...                   ...                   ...
# 99995              629                  2901              630.0000
# 99996              629                  2702              630.0000
# 99997              629                  2904              630.0000
# 99998              630                  2902              701.0000
# 99999              630                  2904              701.0000
#
#        DE18_merchant_category_code  DE19_acquirer_country_code  \
# 0                             7832                          76
# 1                             5541                          76
# 2                             6011                          76
# 3                             6011                          76
# 4                             5541                         840
# ...                            ...                         ...
# 99995                         6011                          76
# 99996                         5541                          76
# 99997                         6011                         392
# 99998                         6011                          76
# 99999                         6011                          76
#
#        DE22_pos_entry_mode  DE23_card_seq_number  DE25_pos_condition_code  \
# 0                       51                1.0000                        0
# 1                       51                2.0000                        0
# 2                       51                1.0000                        0
# 3                       51                2.0000                        0
# 4                       51                2.0000                        0
# ...                    ...                   ...                      ...
# 99995                   51                1.0000                        0
# 99996                   71                3.0000                        0
# 99997                   22                2.0000                        0
# 99998                   22                1.0000                        0
# 99999                   22                2.0000                        0
#
#        DE32_acquiring_institution_id   DE35_track2_data_masked  \
# 0                         8881828076  422355******4250=2705201
# 1                         8881828076  422355******2908=2902201
# 2                         8881828076  541333******2878=2610201
# 3                         8881828076  422355******0490=2807201
# 4                         8881828076  533421******0731=2903201
# ...                              ...                       ...
# 99995                     8881828076  422355******1641=2901201
# 99996                     8881828076  533421******2374=2702201
# 99997                     8881828076  422355******1381=2904201
# 99998                     8881828076  541333******1792=2902201
# 99999                     8881828076  422355******1381=2904201
#
#       DE37_retrieval_reference_number DE38_authorization_code  \
# 0                        VVYLJQRDBRFS                  H1M3X7
# 1                        GTZXO46J719F                  74NLNC
# 2                        T34VRBQVFD68                  FCXJ98
# 3                        8HOW117XS4KW                  BFE8F0
# 4                        KKHI70AU9JOD                  2TQ3CP
# ...                               ...                     ...
# 99995                    NA0GN1BWBDLX                  PSLG8N
# 99996                    QUWQ06KUW48D                  ASPED7
# 99997                    453GS5IFMFQ1                  VTE73O
# 99998                    ZWV37HS91XJV                  0VU5IX
# 99999                    TUE3C96MSW8N                  VYWE83
#
#        DE39_response_code DE41_terminal_id DE42_card_acceptor_id  \
# 0                       0         BR-26205       M75866946948952
# 1                       0         BR-89263       M59412977990756
# 2                       0         BR-41537       M81505175379755
# 3                       0         BR-95461       M46180970941225
# 4                       0         BR-91954       M00894071201871
# ...                   ...              ...                   ...
# 99995                   0         BR-79315       M85997130168524
# 99996                   0         BR-79167       M39928397798171
# 99997                   0         BR-93022       M23453853370010
# 99998                   0         BR-47863       M67201114083228
# 99999                   0         BR-17731       M83336023910717
#
#                DE43_card_acceptor_name_location DE44_additional_response_data  \
# 0      CINEPOLIS             CURITIBA     BR                              NaN
# 1      AXION ENERGY          CURITIBA     BR                              NaN
# 2      ATM SANTANDER         BELOHORIZONTEBR                              NaN
# 3      ATM RED LINK          RIODEJANEIRO BR                              NaN
# 4      SHELL SERVICENTRO     NEWYORK      US                              NaN
# ...                                         ...                           ...
# 99995  ATM RED LINK          RECIFE       BR                              NaN
# 99996  AXION ENERGY          PORTOALEGRE  BR                              NaN
# 99997  ATM BB CAIXA          TOKYO        JP                              NaN
# 99998  ATM RED LINK          RECIFE       BR                              NaN
# 99999  ATM HSBC              RIODEJANEIRO BR                              NaN
#
#        DE48_additional_data  DE49_currency_code_transaction  \
# 0                       NaN                             986
# 1                       NaN                             986
# 2                       NaN                             986
# 3                       NaN                             986
# 4                       NaN                             840
# ...                     ...                             ...
# 99995                   NaN                             986
# 99996                   NaN                             986
# 99997                   NaN                             392
# 99998                   NaN                             986
# 99999                   NaN                             986
#
#        DE50_currency_code_settlement  DE51_currency_code_billing  \
# 0                                986                         986
# 1                                986                         986
# 2                                986                         986
# 3                                986                         986
# 4                                986                         986
# ...                              ...                         ...
# 99995                            986                         986
# 99996                            986                         986
# 99997                            986                         986
# 99998                            986                         986
# 99999                            986                         986
#
#       DE52_pin_data_present  DE54_additional_amounts DE55_emv_data_present  \
# 0                         Y                      NaN                     Y
# 1                         Y                      NaN                     Y
# 2                         Y                      NaN                     Y
# 3                         Y                      NaN                     Y
# 4                         Y                      NaN                     Y
# ...                     ...                      ...                   ...
# 99995                     Y                      NaN                     Y
# 99996                     Y                      NaN                     Y
# 99997                     N                      NaN                     N
# 99998                     N                      NaN                     N
# 99999                     N                      NaN                     N
#
#        DE56_original_data  DE58_authorizing_agent_id DE60_pos_terminal_type  \
# 0                     NaN            8881828076.0000           POS-ATTENDED
# 1                     NaN            8881828076.0000           POS-ATTENDED
# 2                     NaN            8881828076.0000         ATM-UNATTENDED
# 3                     NaN            8881828076.0000         ATM-UNATTENDED
# 4                     NaN            8881828076.0000           POS-ATTENDED
# ...                   ...                        ...                    ...
# 99995                 NaN            8881828076.0000         ATM-UNATTENDED
# 99996                 NaN            8881828076.0000           POS-ATTENDED
# 99997                 NaN            8881828076.0000         ATM-UNATTENDED
# 99998                 NaN            8881828076.0000         ATM-UNATTENDED
# 99999                 NaN            8881828076.0000         ATM-UNATTENDED
#
#        DE61_pos_extended_data DE63_network_specific  \
# 0                      0.0000                BR-PRI
# 1                      0.0000                BR-PRI
# 2                      0.0000                BR-PRI
# 3                      0.0000                BR-PRI
# 4                      0.0000                BR-PRI
# ...                       ...                   ...
# 99995                  0.0000                BR-PRI
# 99996                  0.0000                BR-PRI
# 99997                  0.0000                BR-PRI
# 99998                  0.0000                BR-PRI
# 99999                  0.0000                BR-PRI
#
#        DE100_receiving_institution_id DE102_account_id_1  DE103_account_id_2  \
# 0                     8881828076.0000    ACC762765677939                 NaN
# 1                     8881828076.0000    ACC091899892764                 NaN
# 2                     8881828076.0000    ACC796431724778                 NaN
# 3                     8881828076.0000    ACC887592491481                 NaN
# 4                     8881828076.0000    ACC065520770881                 NaN
# ...                               ...                ...                 ...
# 99995                 8881828076.0000    ACC456033404512                 NaN
# 99996                 8881828076.0000    ACC190886888422                 NaN
# 99997                 8881828076.0000    ACC266182018703                 NaN
# 99998                 8881828076.0000    ACC236892392966                 NaN
# 99999                 8881828076.0000    ACC266182018703                 NaN
#
#       DE123_pos_data_code  amount_local  amount_tx_currency currency_tx_alpha  \
# 0                  05100Y       74.6100             74.6100               BRL
# 1                  05100Y      291.6200            291.6200               BRL
# 2                  05100Y      249.5000            249.5000               BRL
# 3                  05100Y      204.8500            204.8500               BRL
# 4                  05100Y      358.0100             71.6000               USD
# ...                   ...           ...                 ...               ...
# 99995              05100Y      735.9700            735.9700               BRL
# 99996              07100Y      659.0700            659.0700               BRL
# 99997              02200N     1517.6800          45530.4900               JPY
# 99998              02200N     1859.3200           1859.3200               BRL
# 99999              02200N     1988.8400           1988.8400               BRL
#
#        amount_usd  is_international  distance_from_home_km  hour_local  \
# 0         14.9200             False                12.1000          21
# 1         58.3200             False                 2.1000          21
# 2         49.9000             False              1086.0000          21
# 3         40.9700             False                22.6000          21
# 4         71.6000              True              6671.0000          21
# ...           ...               ...                    ...         ...
# 99995    147.1900             False                10.7000          20
# 99996    131.8100             False                16.1000          20
# 99997    303.5400              True              3765.0000          23
# 99998    371.8600             False                12.5000           3
# 99999    397.7700             False              1437.0000          22
#
#       day_of_week  approved response_description  client_baseline_amount  \
# 0             Tue      True             Approved                714.7400
# 1             Tue      True             Approved                640.6700
# 2             Tue      True             Approved                626.3200
# 3             Tue      True             Approved                278.1900
# 4             Tue      True             Approved                664.0900
# ...           ...       ...                  ...                     ...
# 99995         Sun      True             Approved                592.1800
# 99996         Sun      True             Approved                759.1600
# 99997         Sun      True             Approved                569.4300
# 99998         Mon      True             Approved                709.5000
# 99999         Mon      True             Approved                569.4300
#
#       client_home_city  is_fraud source_bank
# 0             CURITIBA     False  BR_PRIVATE
# 1             CURITIBA     False  BR_PRIVATE
# 2               RECIFE     False  BR_PRIVATE
# 3         RIODEJANEIRO     False  BR_PRIVATE
# 4          PORTOALEGRE     False  BR_PRIVATE
# ...                ...       ...         ...
# 99995           RECIFE     False  BR_PRIVATE
# 99996      PORTOALEGRE     False  BR_PRIVATE
# 99997         BRASILIA      True  BR_PRIVATE
# 99998           RECIFE      True  BR_PRIVATE
# 99999         BRASILIA      True  BR_PRIVATE
#
# [100000 rows x 67 columns]

# %%
gt
# Out:
#                              transaction_id bank_code bank_name bank_country  \
# 0      06a94162-7bae-427c-b68c-2819181b5467    GT-EST    GT-EST           GT
# 1      8d261988-07bd-4696-8fe3-ba3526142d2e    GT-EST    GT-EST           GT
# 2      b6be7a48-12fc-40ac-a12f-e2e03637231b    GT-EST    GT-EST           GT
# 3      12d06acb-2241-4d57-bfe2-ebb13750d301    GT-EST    GT-EST           GT
# 4      5ce8b673-fe15-41e1-bacf-91569a3cbe53    GT-EST    GT-EST           GT
# ...                                     ...       ...       ...          ...
# 99995  fd1d6056-2035-4fb7-9db2-04486f2b3f00    GT-EST    GT-EST           GT
# 99996  cf20f0e8-6b35-4a14-b15b-73ea1ce5a8f3    GT-EST    GT-EST           GT
# 99997  7a779906-a704-4422-86ab-4f9467f3054d    GT-EST    GT-EST           GT
# 99998  3bc6d125-9cdc-491c-858a-e730b228437a    GT-EST    GT-EST           GT
# 99999  b8f3299d-be14-414e-9be0-d3aac8842117    GT-EST    GT-EST           GT
#
#       bank_tier           client_id client_segment channel  card_brand  \
# 0       estatal  GT-EST-CL-00004881    PLAN_SUELDO    ECOM        VISA
# 1       estatal  GT-EST-CL-00000966    PLAN_SUELDO    ECOM        VISA
# 2       estatal  GT-EST-CL-00004217    PLAN_SUELDO     POS        VISA
# 3       estatal  GT-EST-CL-00001115    PLAN_SUELDO     ATM        VISA
# 4       estatal  GT-EST-CL-00002868    PLAN_SUELDO    ECOM  MASTERCARD
# ...         ...                 ...            ...     ...         ...
# 99995   estatal  GT-EST-CL-00000508    PLAN_SUELDO    ECOM        VISA
# 99996   estatal  GT-EST-CL-00000225    PLAN_SUELDO     POS        VISA
# 99997   estatal  GT-EST-CL-00002472            NaN    MOTO  MASTERCARD
# 99998   estatal  GT-EST-CL-00000949    PLAN_SUELDO     POS        VISA
# 99999   estatal  GT-EST-CL-00000949    PLAN_SUELDO     POS        VISA
#
#              pan_masked                                           pan_hash  \
# 0      455920******5983  a92f98f97cd8ede91a0dac2dbca2d975e18caf1a2fd444...
# 1      455920******6807  7be1dc2c38ca824693fa11ee4aac7b12ad8f80828b1abd...
# 2      492421******9765  63a13a42dab28e218219585a0dc2f1d393b9b464235e1d...
# 3      492421******3609  b2f8d2e1b8b54189106741ed1303d231131521ff31416a...
# 4      548221******8352  67ad25fd61b95791ce83951fca3ab1f78003a6773b3f93...
# ...                 ...                                                ...
# 99995  455920******7418  78f6738099a95b433b6a3ec09cd16d3eb5aa2dd7bc0cc3...
# 99996  455920******4113  e639867420e828c004adef28ff37350f0f611fbb7dfb90...
# 99997  548221******8285  c33a3504b567460e41640608b73e20c955ae4b8c622e0c...
# 99998  492421******6237  75182f52034c17329222255e446944a98796a299b3dd26...
# 99999  492421******6237  75182f52034c17329222255e446944a98796a299b3dd26...
#
#        MTI               DE2_PAN  DE3_processing_code  DE4_amount_transaction  \
# 0      100 4559210000000000.0000                    0                    3788
# 1      100 4559210000000000.0000                    0                   10092
# 2      100 4924210000000000.0000                    0                    1474
# 3      100 4924210000000000.0000                10000                    6132
# 4      100 5482210000000000.0000                    0                   13979
# ...    ...                   ...                  ...                     ...
# 99995  100 4559210000000000.0000                    0                   36281
# 99996  100 4559210000000000.0000                    0                    4236
# 99997  100 5482210000000000.0000                    0                     846
# 99998  100 4924220000000000.0000                    0                   42243
# 99999  100 4924220000000000.0000                90000                   60921
#
#        DE6_amount_cardholder_billing  DE7_transmission_datetime  \
# 0                               3788                  101000628
# 1                              10092                  101000846
# 2                               1474                  101001257
# 3                               6132                  101001259
# 4                              13979                  101001322
# ...                              ...                        ...
# 99995                          36281                  629235427
# 99996                           4236                  629235644
# 99997                            846                  629235932
# 99998                          42243                  630171116
# 99999                          60921                  701152218
#
#        DE9_conversion_rate_billing  DE11_STAN  DE12_local_time  \
# 0                    10000000.0000     275463           180628
# 1                    10000000.0000     274477           180846
# 2                    10000000.0000     290652           181257
# 3                    10000000.0000     280506           181259
# 4                    10000000.0000     316598           181322
# ...                            ...        ...              ...
# 99995                10000000.0000     267980           175427
# 99996                          NaN     322105           175644
# 99997                10000000.0000     283404           175932
# 99998                10000000.0000     283902           111116
# 99999                10000000.0000     283903            92218
#
#        DE13_local_date  DE14_expiration_date  DE15_settlement_date  \
# 0                 1231                  2807              101.0000
# 1                 1231                  2805              101.0000
# 2                 1231                  2705              101.0000
# 3                 1231                  2709              101.0000
# 4                 1231                  2705              101.0000
# ...                ...                   ...                   ...
# 99995              629                  2708              630.0000
# 99996              629                  2808              630.0000
# 99997              629                  2701              630.0000
# 99998              630                  2904              701.0000
# 99999              701                  2904              702.0000
#
#        DE18_merchant_category_code  DE19_acquirer_country_code  \
# 0                             5999                         320
# 1                             4816                         320
# 2                             7832                         320
# 3                             6011                         320
# 4                             5311                         320
# ...                            ...                         ...
# 99995                         7011                         320
# 99996                         5912                         320
# 99997                         4814                         320
# 99998                         5921                         320
# 99999                         5411                         320
#
#        DE22_pos_entry_mode  DE23_card_seq_number  DE25_pos_condition_code  \
# 0                       81                1.0000                       59
# 1                       81                2.0000                       59
# 2                       21                3.0000                        0
# 3                       51                1.0000                        0
# 4                       81                2.0000                       59
# ...                    ...                   ...                      ...
# 99995                   81                3.0000                       59
# 99996                   51                2.0000                        0
# 99997                   10                3.0000                        8
# 99998                   22                1.0000                        0
# 99999                   22                1.0000                        0
#
#        DE32_acquiring_institution_id   DE35_track2_data_masked  \
# 0                         8112932320  455920******5983=2807201
# 1                         8112932320  455920******6807=2805201
# 2                         8112932320  492421******9765=2705201
# 3                         8112932320  492421******3609=2709201
# 4                         8112932320  548221******8352=2705201
# ...                              ...                       ...
# 99995                     8112932320  455920******7418=2708201
# 99996                     8112932320  455920******4113=2808201
# 99997                     8112932320  548221******8285=2701201
# 99998                     8112932320  492421******6237=2904201
# 99999                     8112932320  492421******6237=2904201
#
#       DE37_retrieval_reference_number DE38_authorization_code  \
# 0                        DUIPJ286IBQD                  NZD1VT
# 1                        9CNQS9I18BAW                  YFZS5V
# 2                        UFJFI8UTAELD                  IR3HCT
# 3                        LB1IIN8KYND5                  FK00G7
# 4                        U17NAQN8M8O5                  39ZPS2
# ...                               ...                     ...
# 99995                    A1J9HZTZIUQH                  N0Y4UW
# 99996                    Q5QK1EAHD7QA                  4URGN3
# 99997                    DOVU6PLL0NTL                  DAEL3L
# 99998                    7Y710JMY8TLQ                     NaN
# 99999                    T1DU80QLUTTD                  YLLESF
#
#        DE39_response_code DE41_terminal_id DE42_card_acceptor_id  \
# 0                       0         GT-31817       M53092173939721
# 1                       0         GT-29794       M53901707180973
# 2                       0         GT-90879       M83171026368737
# 3                       0         GT-96293       M72981131617843
# 4                       0         GT-35709       M08558779819526
# ...                   ...              ...                   ...
# 99995                   0         GT-91244       M93384996517270
# 99996                   0         GT-21003       M10545636586856
# 99997                   0         GT-43746       M33785571758746
# 99998                  62         GT-15667       M64328473068592
# 99999                   0         GT-83403       M12816220128953
#
#                DE43_card_acceptor_name_location DE44_additional_response_data  \
# 0      VARIEDADES MIX        ANTIGUA      GT                              NaN
# 1      VPN PREMIUM           ANTIGUA      GT                              NaN
# 2      HOYTS CINEMA          VILLANUEVA   GT                              NaN
# 3      ATM HSBC              VILLANUEVA   GT                              NaN
# 4      EL CORTE              ESCUINTLA    GT                              NaN
# ...                                         ...                           ...
# 99995  HOTEL HILTON          MIXCO        GT                              NaN
# 99996  FARMACIA CRUZ         VILLANUEVA   GT                              NaN
# 99997  TIM MOBILE            MIXCO        GT                              NaN
# 99998  CAVA DEL VALLE        RETALHULEU   GT                  RESTRICTED CARD
# 99999  EL ABASTO             CHIMALTENANGOGT                              NaN
#
#        DE48_additional_data  DE49_currency_code_transaction  \
# 0                       NaN                             320
# 1                       NaN                             320
# 2                       NaN                             320
# 3                       NaN                             320
# 4                       NaN                             320
# ...                     ...                             ...
# 99995                   NaN                             320
# 99996                   NaN                             320
# 99997                   NaN                             320
# 99998                   NaN                             320
# 99999                   NaN                             320
#
#        DE50_currency_code_settlement  DE51_currency_code_billing  \
# 0                                320                         320
# 1                                320                         320
# 2                                320                         320
# 3                                320                         320
# 4                                320                         320
# ...                              ...                         ...
# 99995                            320                         320
# 99996                            320                         320
# 99997                            320                         320
# 99998                            320                         320
# 99999                            320                         320
#
#       DE52_pin_data_present  DE54_additional_amounts DE55_emv_data_present  \
# 0                         N                      NaN                     N
# 1                         N                      NaN                     N
# 2                         Y                      NaN                     N
# 3                         Y                      NaN                     Y
# 4                         N                      NaN                     N
# ...                     ...                      ...                   ...
# 99995                     N                      NaN                     N
# 99996                     Y                      NaN                     Y
# 99997                     N                      NaN                     N
# 99998                     N                      NaN                     N
# 99999                     N                      NaN                     N
#
#        DE56_original_data  DE58_authorizing_agent_id DE60_pos_terminal_type  \
# 0                     NaN            8112932320.0000           ECOM-VIRTUAL
# 1                     NaN            8112932320.0000           ECOM-VIRTUAL
# 2                     NaN            8112932320.0000           POS-ATTENDED
# 3                     NaN            8112932320.0000         ATM-UNATTENDED
# 4                     NaN                        NaN           ECOM-VIRTUAL
# ...                   ...                        ...                    ...
# 99995                 NaN            8112932320.0000           ECOM-VIRTUAL
# 99996                 NaN            8112932320.0000           POS-ATTENDED
# 99997                 NaN            8112932320.0000             MOTO-CLERK
# 99998                 NaN            8112932320.0000           POS-ATTENDED
# 99999                 NaN            8112932320.0000           POS-ATTENDED
#
#        DE61_pos_extended_data DE63_network_specific  \
# 0                     59.0000                GT-EST
# 1                     59.0000                GT-EST
# 2                      0.0000                GT-EST
# 3                      0.0000                GT-EST
# 4                     59.0000                GT-EST
# ...                       ...                   ...
# 99995                 59.0000                GT-EST
# 99996                  0.0000                GT-EST
# 99997                  8.0000                GT-EST
# 99998                  0.0000                GT-EST
# 99999                  0.0000                GT-EST
#
#        DE100_receiving_institution_id DE102_account_id_1  DE103_account_id_2  \
# 0                     8112932320.0000    ACC847762387971                 NaN
# 1                     8112932320.0000    ACC089928841642                 NaN
# 2                     8112932320.0000    ACC083114000052                 NaN
# 3                     8112932320.0000    ACC357298244128                 NaN
# 4                     8112932320.0000    ACC851567728637                 NaN
# ...                               ...                ...                 ...
# 99995                 8112932320.0000    ACC170879204091                 NaN
# 99996                 8112932320.0000    ACC520293860940                 NaN
# 99997                 8112932320.0000    ACC375956637895                 NaN
# 99998                             NaN    ACC902256758378                 NaN
# 99999                 8112932320.0000    ACC902256758378                 NaN
#
#       DE123_pos_data_code  amount_local  amount_tx_currency currency_tx_alpha  \
# 0                  08159N       37.8800             37.8800               GTQ
# 1                  08159N      100.9200            100.9200               GTQ
# 2                  02100Y       14.7400             14.7400               GTQ
# 3                  05100Y       61.3200             61.3200               GTQ
# 4                  08159N      139.7900            139.7900               GTQ
# ...                   ...           ...                 ...               ...
# 99995              08159N      362.8100            362.8100               GTQ
# 99996              05100Y       42.3600             42.3600               GTQ
# 99997              01008N        8.4600              8.4600               GTQ
# 99998              02200N      422.4300            422.4300               GTQ
# 99999              02200N      609.2100            609.2100               GTQ
#
#        amount_usd  is_international  distance_from_home_km  hour_local  \
# 0          4.8600             False                    NaN          18
# 1         12.9400             False                 8.0000          18
# 2          1.8900             False                 1.7000          18
# 3          7.8600             False                 8.2000          18
# 4         17.9200             False                18.8000          18
# ...           ...               ...                    ...         ...
# 99995     46.5100             False                 3.5000          17
# 99996      5.4300             False                17.4000          17
# 99997      1.0800             False                 1.3000          17
# 99998     54.1600             False              1422.0000          11
# 99999     78.1000             False               583.0000           9
#
#       day_of_week  approved response_description  client_baseline_amount  \
# 0             Tue      True             Approved                164.8400
# 1             Tue      True             Approved                222.4400
# 2             Tue      True             Approved                156.7700
# 3             Tue      True             Approved                 92.0700
# 4             NaN      True             Approved                110.6100
# ...           ...       ...                  ...                     ...
# 99995         Sun      True             Approved                152.0700
# 99996         NaN      True             Approved                100.1700
# 99997         Sun      True             Approved                297.2400
# 99998         Mon     False      Restricted card                231.9900
# 99999         Tue      True             Approved                231.9900
#
#       client_home_city  is_fraud source_bank
# 0              ANTIGUA       NaN    GT_STATE
# 1              ANTIGUA       NaN    GT_STATE
# 2           VILLANUEVA       NaN    GT_STATE
# 3           VILLANUEVA       NaN    GT_STATE
# 4            ESCUINTLA       NaN    GT_STATE
# ...                ...       ...         ...
# 99995            MIXCO       NaN    GT_STATE
# 99996       VILLANUEVA       NaN    GT_STATE
# 99997            MIXCO       NaN    GT_STATE
# 99998        ESCUINTLA       NaN    GT_STATE
# 99999        ESCUINTLA       NaN    GT_STATE
#
# [100000 rows x 67 columns]

# %% [markdown]
# Todos los registros de GT Estatal no tienen la etiquieta **is_fraud**. Tengo 2 opciones, usar GT como test o como dataset final al que le tengo que determinar si es fraudo o no.

# %%
df_train = pd.concat([dfs_raw["BO_VIP"], dfs_raw["BR_PRIVATE"]], ignore_index=True)
df_test  = dfs_raw["GT_STATE"].copy()

print(f"Train shape (BO y BR):  {df_train.shape}")
print(f"Test shape (GT):        {df_test.shape}")
# Out:
# Train shape (BO y BR):  (200003, 67)
# Test shape (GT):        (100000, 67)

# %%
print("Porcentaje de fraude por banco en train:")
print(df_train.groupby("source_bank")["is_fraud"].mean().map("{:.2%}".format))
# Out:
# Porcentaje de fraude por banco en train:
# source_bank
# BO_VIP        4.92%
# BR_PRIVATE    3.21%
# Name: is_fraud, dtype: str

# %% [markdown]
# #### Inspección y Análisis de Nulos

# %%
print("--- Tipos de datos ---")
print(df_train.dtypes.value_counts())
df_train.head(3)
# Out:
# --- Tipos de datos ---
# str        29
# int64      19
# float64    16
# bool        3
# Name: count, dtype: int64
#                          transaction_id bank_code bank_name bank_country  \
# 0  7dd812b1-bd03-4d05-afc6-c318dcc9b651    BO-VIP    BO-VIP           BO
# 1  c08b49a6-889a-491a-a1f8-974526f7886d    BO-VIP    BO-VIP           BO
# 2  b04f88bd-2e33-42e5-a3cf-d52ef22dd7d9    BO-VIP    BO-VIP           BO
#
#   bank_tier           client_id client_segment channel  card_brand  \
# 0       vip  BO-VIP-CL-00001325       PLATINUM     POS  MASTERCARD
# 1       vip  BO-VIP-CL-00000079        PRIVATE    ECOM        VISA
# 2       vip  BO-VIP-CL-00002344       INFINITE    ECOM         NaN
#
#          pan_masked                                           pan_hash  MTI  \
# 0  531270******3773  e253ee7d060689e75077b0c7d85d995bf4ba104a7a931e...  100
# 1  421250******5552  9de2ffd889d660bc1d350aff8143484eaab5246c0c3f31...  100
# 2  531270******6104  14d38149e4bcdeffed96229129ba6d359b477780d24ba0...  100
#
#                 DE2_PAN  DE3_processing_code  DE4_amount_transaction  \
# 0 5312700000000000.0000                    0                   39379
# 1 4212500000000000.0000                    0                 1310264
# 2 5312700000000000.0000                    0                  241394
#
#    DE6_amount_cardholder_billing  DE7_transmission_datetime  \
# 0                         345082                  101000151
# 1                        1310264                  101000355
# 2                         241394                  101000410
#
#    DE9_conversion_rate_billing  DE11_STAN  DE12_local_time  DE13_local_date  \
# 0                87630970.0000     947249           200151             1231
# 1                10000000.0000       7687           200355             1231
# 2                10000000.0000     979481           200410             1231
#
#    DE14_expiration_date  DE15_settlement_date  DE18_merchant_category_code  \
# 0                  2901              101.0000                         5651
# 1                  2907              101.0000                         4511
# 2                  2610              101.0000                         5732
#
#    DE19_acquirer_country_code  DE22_pos_entry_mode  DE23_card_seq_number  \
# 0                         826                   72                1.0000
# 1                          68                   81                2.0000
# 2                          68                   81                2.0000
#
#    DE25_pos_condition_code  DE32_acquiring_institution_id  \
# 0                        0                    14484680068
# 1                       59                    14484680068
# 2                       59                    14484680068
#
#     DE35_track2_data_masked DE37_retrieval_reference_number  \
# 0  531270******3773=2901201                    TEBBJIQJPQP9
# 1  421250******5552=2907201                    115BVLO5H5F0
# 2  531270******6104=2610201                    NUKM3XFSZVJX
#
#   DE38_authorization_code  DE39_response_code DE41_terminal_id  \
# 0                  17P76V                   0         BO-23325
# 1                  48D1XM                   0         BO-34705
# 2                  PFIGFD                   0         BO-31334
#
#   DE42_card_acceptor_id          DE43_card_acceptor_name_location  \
# 0       M74178102540833  LEVIS STORE           LONDON       GB
# 1       M95802681578714  IBERIA                LAPAZ        BO
# 2       M28333044130009  AMAZON ELECTRO        SANTACRUZ    BO
#
#   DE44_additional_response_data  DE48_additional_data  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
#
#    DE49_currency_code_transaction  DE50_currency_code_settlement  \
# 0                             826                             68
# 1                              68                             68
# 2                              68                             68
#
#    DE51_currency_code_billing DE52_pin_data_present  DE54_additional_amounts  \
# 0                          68                     N                      NaN
# 1                          68                     N                      NaN
# 2                          68                     N                      NaN
#
#   DE55_emv_data_present  DE56_original_data  DE58_authorizing_agent_id  \
# 0                     N                 NaN           14484680068.0000
# 1                     N                 NaN           14484680068.0000
# 2                     N                 NaN           14484680068.0000
#
#   DE60_pos_terminal_type  DE61_pos_extended_data DE63_network_specific  \
# 0           POS-ATTENDED                  0.0000                BO-VIP
# 1           ECOM-VIRTUAL                 59.0000                BO-VIP
# 2           ECOM-VIRTUAL                 59.0000                BO-VIP
#
#    DE100_receiving_institution_id DE102_account_id_1  DE103_account_id_2  \
# 0                14484680068.0000    ACC774404459020                 NaN
# 1                14484680068.0000    ACC620405269742                 NaN
# 2                14484680068.0000    ACC606260684104                 NaN
#
#   DE123_pos_data_code  amount_local  amount_tx_currency currency_tx_alpha  \
# 0              07200N     3450.8200            393.7900               GBP
# 1              08159N    13102.6400          13102.6400               BOB
# 2              08159N     2413.9400           2413.9400               BOB
#
#    amount_usd  is_international  distance_from_home_km  hour_local  \
# 0    500.1200              True              8717.0000          20
# 1   1898.9300             False                 4.9000          20
# 2    349.8500             False                 4.4000          20
#
#   day_of_week  approved response_description  client_baseline_amount  \
# 0         Tue      True             Approved               2012.5100
# 1         Tue      True             Approved               1096.4600
# 2         Tue      True             Approved               1528.3700
#
#   client_home_city  is_fraud source_bank
# 0           TARIJA     False      BO_VIP
# 1            LAPAZ     False      BO_VIP
# 2        SANTACRUZ     False      BO_VIP

# %%
null_pct = df_train.isnull().mean() * 100
null_pct = null_pct.sort_values(ascending=False)
null_pct_nonzero = null_pct[null_pct > 0]

fig, ax = plt.subplots(figsize=(10, 6))
null_pct_nonzero.plot(kind="barh", ax=ax, color="steelblue")
ax.set_xlabel("% de valores nulos")
ax.set_title("Porcentaje de valores nulos por columna (df_train)")
ax.axvline(90, color="red", linestyle="--", label="90%")
ax.legend()
plt.tight_layout()
plt.show()

# %%
print("\nColumnas con >90% nulos:")
print(null_pct[null_pct > 90].index.tolist())
# Out:
# Columnas con >90% nulos:
# ['DE54_additional_amounts', 'DE56_original_data', 'DE103_account_id_2', 'DE48_additional_data', 'DE44_additional_response_data']

# %% [markdown]
# DE54 - additional_amounts
#     Montos adicionales (ej: cashback, propina, balance de cuenta).
#     **Indicaría que la que la mayoria de transacciones en este dataset no tiene montos adicionales**
#
# DE56_original_data, DE103_account_id_2, DE48_additional_data, DE44_additional_response_data **no están descritos y son mayormente nulos**

# %%
duplicadas = bo.T[bo.T.duplicated()]
duplicadas
# Out:
#                             0       1       2       3       4       5       \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             6       7       8       9       10      11      \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             12      13      14      15      16      17      \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             18      19      20      21      22      23      \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             24      25      26      27      28      29      \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             30      31      32      33      34      35      \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             36      37      38      39      ...  99963   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  ...  BO-VIP
# DE51_currency_code_billing      68      68      68      68  ...      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN  ...     NaN
# DE56_original_data             NaN     NaN     NaN     NaN  ...     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN  ...     NaN
#
#                             99964   99965   99966   99967   99968   99969   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             99970   99971   99972   99973   99974   99975   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             99976   99977   99978   99979   99980   99981   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             99982   99983   99984   99985   99986   99987   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             99988   99989   99990   99991   99992   99993   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             99994   99995   99996   99997   99998   99999   \
# bank_name                   BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN     NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN     NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN     NaN     NaN     NaN
#
#                             100000  100001  100002
# bank_name                   BO-VIP  BO-VIP  BO-VIP
# DE51_currency_code_billing      68      68      68
# DE54_additional_amounts        NaN     NaN     NaN
# DE56_original_data             NaN     NaN     NaN
# DE103_account_id_2             NaN     NaN     NaN
#
# [5 rows x 100003 columns]

# %% [markdown]
# ---
# ## 3. Limpieza de Datos
#
# Eliminación de columnas con >90% nulos

# %%
COLS_DROP_NULL = [
    "DE56_original_data",       
    "DE103_account_id_2",       
    "DE54_additional_amounts",  
    "DE48_additional_data",     
    "DE44_additional_response_data",
]

# %% [markdown]
# Elimino columas de identificación/trazabilidad que no aportarian a modelos

# %%
COLS_DROP_ID = [
    "transaction_id",
    "pan_masked",
    "pan_hash",
    "DE2_PAN",
    "DE11_STAN",
    "DE37_retrieval_reference_number",  # referencia interna
    "DE35_track2_data_masked",
    "DE43_card_acceptor_name_location", # texto libre
    "DE58_authorizing_agent_id",
    "DE63_network_specific",
    "DE56_original_data",
]

# %% [markdown]
# Columnas que derivan de otras o son redundantes

# %%
COLS_DROP_REDUNDANT = [
    "DE12_local_time",# hour_local ya tiene la info, pero solo hora
    "DE13_local_date",# D/ tiene la misma info pero mas detallada
    "DE50_currency_code_settlement", # igual a DE49 en su mayoría
    "DE51_currency_code_billing", # igual a DE49 en su mayoría
    "bank_name", # redundante con bank_code
    "bank_country", # redundante con source_bank
    "DE15_settlement_date", # irrelevante para un entrenamiento fraude
]

# %%
final_list = list(set(COLS_DROP_NULL + COLS_DROP_ID + COLS_DROP_REDUNDANT))

def clean_drop(df):
    cols = [c for c in final_list if c in df.columns]
    return df.drop(columns=cols)

df_train = clean_drop(df_train)
df_test  = clean_drop(df_test)

print(df_train.shape)
print(df_test.shape)
# Out:
# (200003, 45)
# (100000, 45)

# %%
before = len(df_train)
df_train = df_train.drop_duplicates()
print(f"Filas eliminadas por duplicado: {before - len(df_train)}")
# Out:
# Filas eliminadas por duplicado: 0

# %% [markdown]
# Parsear fechas

# %%
df_train["DE7_transmission_datetime"] = pd.to_datetime(
    df_train["DE7_transmission_datetime"], errors="coerce"
)
df_test["DE7_transmission_datetime"] = pd.to_datetime(
    df_test["DE7_transmission_datetime"], errors="coerce"
)

df_train["tx_month"]    = df_train["DE7_transmission_datetime"].dt.month
df_train["tx_day"]      = df_train["DE7_transmission_datetime"].dt.day
df_train["tx_hour"]     = df_train["DE7_transmission_datetime"].dt.hour
df_train["tx_weekday"]  = df_train["DE7_transmission_datetime"].dt.dayofweek

df_test["tx_month"]    = df_test["DE7_transmission_datetime"].dt.month
df_test["tx_day"]      = df_test["DE7_transmission_datetime"].dt.day
df_test["tx_hour"]     = df_test["DE7_transmission_datetime"].dt.hour
df_test["tx_weekday"]  = df_test["DE7_transmission_datetime"].dt.dayofweek

df_train.drop(columns=["DE7_transmission_datetime"], inplace=True)
df_test.drop(columns=["DE7_transmission_datetime"], inplace=True)

# %% [markdown]
# Relleno de nulos

# %%
df_train.isna().sum()
# Out:
# bank_code                            0
# bank_tier                            0
# client_id                            0
# client_segment                    2087
# channel                              0
# card_brand                        2052
# MTI                                  0
# DE3_processing_code                  0
# DE4_amount_transaction               0
# DE6_amount_cardholder_billing        0
# DE9_conversion_rate_billing       2013
# DE14_expiration_date                 0
# DE18_merchant_category_code          0
# DE19_acquirer_country_code           0
# DE22_pos_entry_mode                  0
# DE23_card_seq_number              2044
# DE25_pos_condition_code              0
# DE32_acquiring_institution_id        0
# DE38_authorization_code           5768
# DE39_response_code                   0
# DE41_terminal_id                  2030
# DE42_card_acceptor_id             1997
# DE49_currency_code_transaction       0
# DE52_pin_data_present                0
# DE55_emv_data_present                0
# DE60_pos_terminal_type               0
# DE61_pos_extended_data            1981
# DE100_receiving_institution_id    2060
# DE102_account_id_1                2016
# DE123_pos_data_code               1943
# amount_local                         0
# amount_tx_currency                   0
# currency_tx_alpha                    0
# amount_usd                           0
# is_international                     0
# distance_from_home_km             1955
# hour_local                           0
# day_of_week                       2029
# approved                             0
# response_description              2046
# client_baseline_amount               0
# client_home_city                     0
# is_fraud                             0
# source_bank                          0
# tx_month                             0
# tx_day                               0
# tx_hour                              0
# tx_weekday                           0
# dtype: int64

# %%
# Numéricos a  mediana
num_cols = df_train.select_dtypes(include=np.number).columns.tolist()
for col in num_cols:
    if df_train[col].isna().any():
        median_val = df_train[col].median()
        df_train[col].fillna(median_val, inplace=True)
        df_test[col].fillna(median_val, inplace=True)

# Categóricos a "UNKNOWN"
cat_cols = df_train.select_dtypes(include="object").columns.tolist()
for col in cat_cols:
    if df_train[col].isna().any():
        df_train[col].fillna("UNKNOWN", inplace=True)
        df_test[col].fillna("UNKNOWN", inplace=True)

print(f"Nulos restantes en train: {df_train.isnull().sum().sum()}")
print(f"Nulos restantes en test:  {df_test.isnull().sum().sum()}")
# Out:
# Nulos restantes en train: 32021
# Nulos restantes en test:  141983

# %% [markdown]
# ---
# ## 4. Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# Tasa de fraude

# %%
print("Porcentaje de fraude por banco en train:")
print(df_train.groupby("source_bank")["is_fraud"].mean().map("{:.2%}".format))
# Out:
# Porcentaje de fraude por banco en train:
# source_bank
# BO_VIP        4.92%
# BR_PRIVATE    3.21%
# Name: is_fraud, dtype: str

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Global
fraud_counts = df_train["is_fraud"].value_counts()
axes[0].pie(fraud_counts, labels=["Legítima", "Fraude"], autopct="%1.2f%%",
            colors=["#4c72b0", "#dd8452"], startangle=90)
axes[0].set_title("Distribución global (train)")

# Por banco
fraud_by_bank = df_train.groupby("source_bank")["is_fraud"].mean().reset_index()
fraud_by_bank.columns = ["Banco", "Tasa de fraude"]
sns.barplot(data=fraud_by_bank, x="Banco", y="Tasa de fraude", ax=axes[1], palette="muted")
axes[1].yaxis.set_major_formatter(mticker.PercentFormatter(1.0))
axes[1].set_title("Tasa de fraude por banco")
axes[1].set_ylim(0, 0.08)

plt.suptitle("Variable objetivo: is_fraud", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# Distribución por cantidad de moneda

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

for ax, col, label in zip(axes,
                           ["amount_usd", "amount_local"],
                           ["Monto USD", "Monto moneda local"]):
    for fraud_val, color, lbl in [(0, "#4c72b0", "Legítima"), (1, "#dd8452", "Fraude")]:
        subset = df_train[df_train["is_fraud"] == fraud_val][col]
        # logarithmic bin histogram
        data = subset[subset > 0]
        ax.hist(np.log1p(data), bins=60, alpha=0.6, color=color, label=lbl, density=True)
    ax.set_xlabel(f"log(1 + {label})")
    ax.set_ylabel("Densidad")
    ax.set_title(f"Distribución de {label}")
    ax.legend()

plt.suptitle("Distribución de montos: Fraude vs Legítima", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
print("Estadísticas de amount_usd:")
print(df_train.groupby("is_fraud")["amount_usd"].describe().T)
# Out:
# Estadísticas de amount_usd:
# is_fraud       False     True
# count    191879.0000 8124.0000
# mean        263.7462  803.6317
# std         424.9072  917.3485
# min           0.2900    0.0700
# 25%          51.9500  211.8825
# 50%         114.8700  467.7500
# 75%         262.8100 1031.3525
# max        6109.4700 6731.9000

# %% [markdown]
# Por hora del día

# %%
fraud_day = df_train.groupby("day_of_week")["is_fraud"].mean()
fraud_day
# Out:
# day_of_week
# Fri   0.0413
# Mon   0.0398
# Sat   0.0434
# Sun   0.0376
# Thu   0.0393
# Tue   0.0395
# Wed   0.0431
# Name: is_fraud, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Por hora
fraud_hour = df_train.groupby("hour_local")["is_fraud"].mean()
axes[0].bar(fraud_hour.index, fraud_hour.values, color="#4c72b0")
axes[0].yaxis.set_major_formatter(mticker.PercentFormatter(1.0))
axes[0].set_xlabel("Hora local")
axes[0].set_ylabel("Tasa de fraude")
axes[0].set_title("Tasa de fraude por hora del día")

# Por día de la semana — day_of_week son abreviaciones de texto ("Mon", "Tue", ...)
DAY_ORDER = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
fraud_day = (df_train.groupby("day_of_week")["is_fraud"]
             .mean()
             .reindex(DAY_ORDER)   # orden lunes → domingo
             .dropna())

axes[1].bar(range(len(fraud_day)), fraud_day.values, color="#dd8452",
            tick_label=fraud_day.index.tolist())
axes[1].yaxis.set_major_formatter(mticker.PercentFormatter(1.0))
axes[1].set_xlabel("Día de la semana")
axes[1].set_ylabel("Tasa de fraude")
axes[1].set_title("Tasa de fraude por día de la semana")

plt.tight_layout()
plt.show()

# %%
# -----------------------------------------------------------------
# 4.4  Variables categóricas clave vs is_fraud
# -----------------------------------------------------------------
cat_features = [
    ("channel",          "Canal de transacción"),
    ("DE22_pos_entry_mode", "POS Entry Mode"),
    ("DE25_pos_condition_code", "POS Condition Code"),
    ("is_international", "Internacional"),
    ("DE52_pin_data_present", "PIN usado"),
    ("DE55_emv_data_present", "EMV/Chip usado"),
    ("card_brand",       "Marca de tarjeta"),
]

fig, axes = plt.subplots(3, 3, figsize=(16, 12))
axes = axes.flatten()

for i, (col, title) in enumerate(cat_features):
    if col not in df_train.columns:
        axes[i].set_visible(False)
        continue
    fraud_rate = df_train.groupby(col)["is_fraud"].mean().sort_values(ascending=False)
    # mantener top-10 categorías para legibilidad
    fraud_rate = fraud_rate.head(10)
    axes[i].bar(range(len(fraud_rate)), fraud_rate.values, color="#4c72b0")
    axes[i].set_xticks(range(len(fraud_rate)))
    axes[i].set_xticklabels(fraud_rate.index.astype(str), rotation=45, ha="right", fontsize=8)
    axes[i].yaxis.set_major_formatter(mticker.PercentFormatter(1.0))
    axes[i].set_title(title, fontsize=9)
    axes[i].set_ylabel("Tasa fraude")

for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle("Tasa de fraude por variable categórica", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# -----------------------------------------------------------------
# 4.5  Top MCC por tasa de fraude
# -----------------------------------------------------------------
mcc_fraud = (df_train.groupby("DE18_merchant_category_code")
             .agg(n_tx=("is_fraud", "count"), fraud_rate=("is_fraud", "mean"))
             .query("n_tx >= 100")  # al menos 100 transacciones
             .sort_values("fraud_rate", ascending=False)
             .head(15)
             .reset_index())

fig, ax = plt.subplots(figsize=(10, 5))
bars = ax.barh(mcc_fraud["DE18_merchant_category_code"].astype(str),
               mcc_fraud["fraud_rate"], color="#dd8452")
ax.xaxis.set_major_formatter(mticker.PercentFormatter(1.0))
ax.set_xlabel("Tasa de fraude")
ax.set_title("Top 15 MCC con mayor tasa de fraude (mín 100 tx)")
ax.invert_yaxis()

for bar, n in zip(bars, mcc_fraud["n_tx"]):
    ax.text(bar.get_width() + 0.001, bar.get_y() + bar.get_height()/2,
            f"n={n:,}", va="center", fontsize=7)

plt.tight_layout()
plt.show()

# %% [markdown]
# Correlación de variables numericas con fraude

# %%
num_cols_train = df_train.select_dtypes(include=[np.number, bool]).columns.tolist()

corr_with_fraud = (df_train[num_cols_train]
                   .astype(float)          # bool → float para que .corr() funcione
                   .corr()["is_fraud"]
                   .drop("is_fraud", errors="ignore")
                   .sort_values(key=abs, ascending=False)
                   .head(20))

fig, ax = plt.subplots(figsize=(10, 6))
colors = ["#dd8452" if v > 0 else "#4c72b0" for v in corr_with_fraud.values]
ax.barh(corr_with_fraud.index, corr_with_fraud.values, color=colors)
ax.axvline(0, color="black", linewidth=0.8)
ax.set_xlabel("Correlación de Pearson con is_fraud")
ax.set_title("Top 20 variables numéricas correlacionadas con fraude")
ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ##   Ingeniería de Características (Feature Engineering)

# %%
def feature_engineering(df, client_stats=None, fit=True):
    df = df.copy()

    # --- 1 Features temporales ---
    df["is_weekend"]  = df["day_of_week"].isin(["Sat", "Sun"]).astype(int)
    df["is_night"]    = df["hour_local"].between(0, 5).astype(int)
    df["hour_sin"]    = np.sin(2 * np.pi * df["hour_local"] / 24)
    df["hour_cos"]    = np.cos(2 * np.pi * df["hour_local"] / 24)

    # --- 2 Features de canal ---
    df["is_online"]       = df["DE22_pos_entry_mode"].isin(["081", "810", "81", 81]).astype(int)
    df["is_contactless"]  = df["DE22_pos_entry_mode"].isin(["070", "710", "70", 70]).astype(int)
    df["is_manual_entry"] = df["DE22_pos_entry_mode"].isin(["010", "10", 10]).astype(int)
    df["is_fallback"]     = df["DE22_pos_entry_mode"].isin(["080", "80", 80]).astype(int)

    cnp_modes = ["081", "810", "81", 81, "010", "10", 10]
    df["is_cnp"] = (
        df["DE22_pos_entry_mode"].isin(cnp_modes) |
        df["DE25_pos_condition_code"].isin(["01", "08", "59", 1, 8, 59])
    ).astype(int)

    # PIN y EMV: Y/N → 0/1
    df["pin_used"] = (df["DE52_pin_data_present"].astype(str).str.upper() == "Y").astype(int)
    df["emv_used"] = (df["DE55_emv_data_present"].astype(str).str.upper() == "Y").astype(int)

    # approved: bool → int (True→1, False→0); reemplaza a la columna original
    # para evitar que aparezcan dos columnas idénticas (approved + approved_int)
    df["approved_int"] = df["approved"].astype(bool).astype(int)
    df.drop(columns=["approved"], inplace=True)

    # --- 3 Montos ---
    df["amount_usd_log"]             = np.log1p(df["amount_usd"])
    df["client_baseline_amount_log"] = np.log1p(df["client_baseline_amount"])
    df["amount_ratio_baseline"]      = df["amount_usd"] / (df["client_baseline_amount"] + 1)
    df["amount_above_baseline"]      = (df["amount_usd"] > df["client_baseline_amount"]).astype(int)

    # --- 4 Ubicación ---
    df["is_international"] = df["is_international"].astype(int)
    df["distance_log"]     = np.log1p(df["distance_from_home_km"])
    df["high_distance"]    = (df["distance_from_home_km"] > 500).astype(int)

    # --- 5 Conversión de moneda ---
    df["has_conversion"] = (df["DE9_conversion_rate_billing"] != 1.0).astype(int)

    # --- 6 Stats por cliente ---
    if fit:
        agg_dict = {
            "client_tx_count":   ("amount_usd", "count"),
            "client_avg_amount": ("amount_usd", "mean"),
            "client_std_amount": ("amount_usd", "std"),
        }
        if "is_fraud" in df.columns:
            agg_dict["client_fraud_rate"] = ("is_fraud", "mean")
        client_stats = df.groupby("client_id").agg(**agg_dict).reset_index()

    # Eliminar columnas de stats anteriores para evitar columnas _x/_y en el merge
    stats_cols = ["client_tx_count", "client_avg_amount",
                  "client_std_amount", "client_fraud_rate",
                  "client_tx_count_x", "client_avg_amount_x", "client_std_amount_x",
                  "client_tx_count_y", "client_avg_amount_y", "client_std_amount_y"]
    df.drop(columns=[c for c in stats_cols if c in df.columns], inplace=True)

    df = df.merge(client_stats, on="client_id", how="left")
    df["client_std_amount"] = df["client_std_amount"].fillna(0)
    df["amount_zscore"] = (
        (df["amount_usd"] - df["client_avg_amount"]) / (df["client_std_amount"] + 1e-6)
    )

    # --- 7 MCC de riesgo ---
    HIGH_RISK_MCC = {6011, 6051, 7995, 5912, 4829, 6010}
    df["mcc_high_risk"] = df["DE18_merchant_category_code"].isin(HIGH_RISK_MCC).astype(int)

    # --- 8 Respuesta ---
    df["tx_declined"] = (df["DE39_response_code"] != "00").astype(int)

    return df, client_stats

df_train, client_stats_train = feature_engineering(df_train, fit=True)
df_test, _ = feature_engineering(df_test, client_stats=client_stats_train, fit=False)

print(f"Train shape: {df_train.shape}")
print(f"Test  shape: {df_test.shape}")
print(f"\npin_used    → {df_train['pin_used'].value_counts().to_dict()}")
print(f"emv_used    → {df_train['emv_used'].value_counts().to_dict()}")
print(f"approved_int únicos → {sorted(df_train['approved_int'].unique())}")
# Out:
# Train shape: (200003, 85)
# Test  shape: (100000, 85)
#
# pin_used    → {0: 107535, 1: 92468}
# emv_used    → {0: 118632, 1: 81371}
# approved_int únicos → [np.int64(0), np.int64(1)]

# %%
from sklearn.preprocessing import LabelEncoder

CAT_ENCODE = [
    "bank_tier", "client_segment", "channel", "card_brand",
    "DE3_processing_code", "DE22_pos_entry_mode", "DE25_pos_condition_code",
    "DE39_response_code", "DE49_currency_code_transaction", "currency_tx_alpha",
    "MTI", "source_bank",
]

label_encoders = {}
for col in CAT_ENCODE:
    if col in df_train.columns:
        le = LabelEncoder()
        df_train[col + "_enc"] = le.fit_transform(df_train[col].astype(str))
        # Para test: categorías desconocidas → -1
        mapping = {v: i for i, v in enumerate(le.classes_)}
        df_test[col + "_enc"] = df_test[col].astype(str).map(mapping).fillna(-1).astype(int)
        label_encoders[col] = le

print("Columnas codificadas:", [c for c in CAT_ENCODE if c in df_train.columns])
# Out:
# Columnas codificadas: ['bank_tier', 'client_segment', 'channel', 'card_brand', 'DE3_processing_code', 'DE22_pos_entry_mode', 'DE25_pos_condition_code', 'DE39_response_code', 'DE49_currency_code_transaction', 'currency_tx_alpha', 'MTI', 'source_bank']

# %% [markdown]
# ---
# ## Construcción del Dataset Final para Entrenamiento

# %%
FEATURES = [
    # de tiempo
    "hour_local", "hour_sin", "hour_cos", "is_weekend", "is_night",
    "tx_month", "tx_weekday",
    
    # Montos
    "amount_usd_log", "amount_local", "client_baseline_amount_log",
    "amount_ratio_baseline", "amount_above_baseline", "amount_zscore",
    
    # Canal / POS
    "is_online", "is_contactless", "is_manual_entry", "is_fallback", "is_cnp",
    "DE52_pin_data_present", "DE55_emv_data_present",
    
    # Ubicación
    "is_international", "distance_log", "high_distance",
   
    # Comportamiento cliente
    "client_tx_count", "client_avg_amount", "client_std_amount",
   
    # MCC
    "mcc_high_risk",
 
    # Conversión / respuesta
    "has_conversion", "tx_declined", "approved_int",
 
    # Categóricas codificadas
    "bank_tier_enc", "client_segment_enc", "channel_enc", "card_brand_enc",
    "DE3_processing_code_enc", "DE22_pos_entry_mode_enc",
    "DE25_pos_condition_code_enc", "DE39_response_code_enc",
    "DE49_currency_code_transaction_enc", "MTI_enc", "source_bank_enc",
]

# %%
FEATURES = [f for f in FEATURES if f in df_train.columns]
TARGET = "is_fraud"

X_train = df_train[FEATURES]
y_train = df_train[TARGET].astype(int)
X_test  = df_test[FEATURES]

print(f"X_train: {X_train.shape}  |  y_train distribución: {y_train.value_counts().to_dict()}")
print(f"X_test:  {X_test.shape}")
print(f"\nFeatures seleccionadas ({len(FEATURES)}):")
for f in FEATURES:
    print(f"  - {f}")
# Out:
# X_train: (200003, 41)  |  y_train distribución: {0: 191879, 1: 8124}
# X_test:  (100000, 41)
#
# Features seleccionadas (41):
#   - hour_local
#   - hour_sin
#   - hour_cos
#   - is_weekend
#   - is_night
#   - tx_month
#   - tx_weekday
#   - amount_usd_log
#   - amount_local
#   - client_baseline_amount_log
#   - amount_ratio_baseline
#   - amount_above_baseline
#   - amount_zscore
#   - is_online
#   - is_contactless
#   - is_manual_entry
#   - is_fallback
#   - is_cnp
#   - DE52_pin_data_present
#   - DE55_emv_data_present
#   - is_international
#   - distance_log
#   - high_distance
#   - client_tx_count
#   - client_avg_amount
#   - client_std_amount
#   - mcc_high_risk
#   - has_conversion
#   - tx_declined
#   - approved_int
#   - bank_tier_enc
#   - client_segment_enc
#   - channel_enc
#   - card_brand_enc
#   - DE3_processing_code_enc
#   - DE22_pos_entry_mode_enc
#   - DE25_pos_condition_code_enc
#   - DE39_response_code_enc
#   - DE49_currency_code_transaction_enc
#   - MTI_enc
#   - source_bank_enc

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

bad_cols = X_train.select_dtypes(include=["object", "bool"]).columns.tolist()
if bad_cols:
    print(f"Columnas no numéricas encontradas en X_train: {bad_cols}")
    print("  Se eliminarán del conjunto de features antes de entrenar.")
    FEATURES_CLEAN = [f for f in FEATURES if f not in bad_cols]
    X_train_clean = X_train[FEATURES_CLEAN]
    X_test_clean  = X_test[FEATURES_CLEAN]
else:
    print("✓ Todas las columnas son numéricas.")
    FEATURES_CLEAN = FEATURES
    X_train_clean  = X_train
    X_test_clean   = X_test

print(f"\nFeatures finales para entrenamiento: {len(FEATURES_CLEAN)}")

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train_clean, y_train, test_size=0.2, random_state=42, stratify=y_train
)

rf = RandomForestClassifier(n_estimators=100, max_depth=8,
                             class_weight="balanced", random_state=42, n_jobs=-1)
rf.fit(X_tr, y_tr)

importances = pd.Series(rf.feature_importances_, index=FEATURES_CLEAN).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 8))
importances.head(25).plot(kind="barh", ax=ax, color="#4c72b0")
ax.invert_yaxis()
ax.set_title("Importancia de features (Random Forest — top 25)")
ax.set_xlabel("Importancia (Gini)")
plt.tight_layout()
plt.show()

print("\nTop 10 features más importantes:")
print(importances.head(10).to_string())
# Out:
# ⚠ Columnas no numéricas encontradas en X_train: ['DE52_pin_data_present', 'DE55_emv_data_present']
#   Se eliminarán del conjunto de features antes de entrenar.
#
# Features finales para entrenamiento: 39
# Top 10 features más importantes:
# amount_ratio_baseline     0.1994
# amount_usd_log            0.1508
# amount_zscore             0.0902
# amount_local              0.0753
# DE39_response_code_enc    0.0663
# approved_int              0.0657
# distance_log              0.0503
# is_international          0.0378
# DE22_pos_entry_mode_enc   0.0361
# high_distance             0.0332

# %%
from sklearn.metrics import (classification_report, roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay)

y_pred  = rf.predict(X_val)
y_proba = rf.predict_proba(X_val)[:, 1]

print("=== Classification Report (validación 20%) ===")
print(classification_report(y_val, y_pred, target_names=["Legítima", "Fraude"], digits=4))
print(f"ROC-AUC: {roc_auc_score(y_val, y_proba):.4f}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
ConfusionMatrixDisplay.from_predictions(y_val, y_pred,
    display_labels=["Legítima", "Fraude"], ax=axes[0], colorbar=False)
axes[0].set_title("Matriz de confusión")

RocCurveDisplay.from_predictions(y_val, y_proba, ax=axes[1])
axes[1].set_title(f"Curva ROC (AUC = {roc_auc_score(y_val, y_proba):.3f})")
plt.tight_layout()
plt.show()
# Out:
# === Classification Report (validación 20%) ===
#               precision    recall  f1-score   support
#
#     Legítima     0.9895    0.9066    0.9462     38376
#       Fraude     0.2595    0.7729    0.3886      1625
#
#     accuracy                         0.9012     40001
#    macro avg     0.6245    0.8398    0.6674     40001
# weighted avg     0.9598    0.9012    0.9236     40001
#
# ROC-AUC: 0.8756

# %%
X_train.assign(is_fraud=y_train).to_csv("dataset_train_final.csv", index=False)
X_test.to_csv("dataset_test_final.csv", index=False)

print("Archivos guardados:")
print(f"  dataset_train_final.csv  → {X_train.shape[0]:,} filas, {X_train.shape[1]} features + target")
print(f"  dataset_test_final.csv   → {X_test.shape[0]:,} filas, {X_test.shape[1]} features (sin target)")
print(f"\nResumen del dataset de entrenamiento:")
print(f"  Transacciones legítimas: {(y_train==0).sum():,}  ({(y_train==0).mean():.2%})")
print(f"  Transacciones fraudulentas: {(y_train==1).sum():,}  ({(y_train==1).mean():.2%})")
print(f"  Total features: {len(FEATURES)}")
# Out:
# Archivos guardados:
#   dataset_train_final.csv  → 200,003 filas, 41 features + target
#   dataset_test_final.csv   → 100,000 filas, 41 features (sin target)
#
# Resumen del dataset de entrenamiento:
#   Transacciones legítimas: 191,879  (95.94%)
#   Transacciones fraudulentas: 8,124  (4.06%)
#   Total features: 41
